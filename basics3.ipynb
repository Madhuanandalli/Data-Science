# %%
#int
age = 20
score = 100
print("age:",age, "score:",score)
# Out:
# age: 20 score: 100

# %%
#float
price = 9.99
pi = 3.14
print(price ,pi)
# Out:
# 9.99 3.14

# %%
#string
name = "zoro"
city = "koppal"
print(name , city)
# Out:
# zoro koppal

# %%
#boolean
is_student = True
passed = False
print(is_student, passed)
# Out:
# True False

# %%
name = "zoro"
age = 20
marks = 99.9
is_student = True

print(name)
print(age)
print(marks)
print(is_student)
# Out:
# zoro
# 20
# 99.9
# True

# %%
name = "Rahul"
age = 20

# f-string: put variable inside { } directly in text
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Rahul and I am 20 years old

# %%
# input() waits for user to type something
name = input("Enter your name: ")
age = int(input("Enter your age: "))

# int() converts text → number (important!)
print(f"Hello {name}! You are {age} years old.")
# Out:
# Enter your name:  zoro
# Enter your age:  21
# Hello zoro! You are 21 years old.

# %%
# if else condition if true run if block , if false run else block
age = 18
if age >= 18:
    print("you can vote!")
else:
    print("too young to vote")
# Out:
# you can vote!

# %%
marks = 75

if marks >= 96:
    print("grade: A")
elif marks >= 78:
    print("grade: B")
elif marks >= 65:
    print("grade: C")
else:
    print("grade: F")
# Out:
# grade: C

# %%
num = -7

if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("zero")
# Out:
# negative

# %%
a = 45
b = 76

if a > b:
    print(f"largest is {a}")
else:
    print(f"largest is {b}")
# Out:
# largest is 76

# %%
num = 14
if num % 2 == 0:
    print(f"{num} is Even")
else:
    print(f"{num} is Odd")
# Out:
# 14 is Even

# %%
#Use elif for the middle condition. Check: is temp > 35? Or is temp >= 20? Otherwise it's cold.

temp = 45
temp = int(input('enter temperature: '))
if temp >= 40:
    print("too hot")
elif temp >= 25:
    print("just right!")
else:
    print("too cold")
# Out:
# enter temperature:  10
# too cold

# %%
for i in range (5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# range(stop) → 0 to stop-1
for i in range(3):
    print(i)# 0, 1, 2
# Out:
# 0
# 1
# 2

# %%
# range(start, stop) → start to stop-1
for i in range(1, 6):
    print(i)# 1, 2, 3, 4, 5
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# range(start, stop, step) → jump by step
for i in range(0, 10, 2):
    print(i)# 0, 2, 4, 6,
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
fruits = ["apple","banana","mango"]

for fruit in fruits:
    print(f"i like {fruit}")
# Out:
# i like apple
# i like banana
# i like mango

# %%
# Out:
# I like apple
# I like banana
# I like mango

# %%
# chech type   type conversion  print(type(x))
num = "10"
num = int(num)

price = 100
price = str(price)
print(num, price)
# Out:
# 10 100

# %%
# airthmetic operator
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
# comparison
print(a > b)
print(a == b)
print(a != b)
# Out:
# True
# False
# True

# %%
# logical
print(True and False)
print(True or False)
print(not True)
# Out:
# False
# True
# False

# %%
# membership
name = "Madhu"

print("M" in name)
print("z" not in name)
# Out:
# True
# True

# %%
# identity
x = [1, 2]
y = x

print(x is y)
# Out:
# True

# %%
# input
name = input("Enter Name: ")
# Out:
# Enter Name:  madhu

# %%
# output
print("Welcome", name)
# Out:
# Welcome madhu

# %%
# f string
name = "Madhu"
age = 22

print(f"My name is {name} and age is {age}")
# Out:
# My name is Madhu and age is 22

# %%
# indexing
text = "Python"

print(text[0])
print(text[-1])
# Out:
# P
# n

# %%
# slicing
print(text[0:3])
print(text[2:])
# Out:
# Pyt
# thon

# %%
# methods
text = "python"

print(text.upper())
print(text.capitalize())
print(text.replace("p", "P"))
# Out:
# PYTHON
# Python
# Python

# %%
# escape characters
print("I can't come")

print("Hello\nWorld")
print("Hello\tWorld")
# Out:
# I can't come
# Hello
# World
# Hello	World

# %%
age = 18

if age >= 18:
    print("Eligible")
# Out:
# Eligible

# %%
if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible

# %%
marks = 85

if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
else:
    print("C")
# Out:
# B

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
for i in range(5):
    pass

# %%
def greet():
    print("Hello")
