# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

print(pd.__version__)
print(sklearn.__version__)
# Out:
# 3.0.5
# 1.9.0

# %%
import sys
print(sys.executable)
# Out:
# /home/zoro/Python/myenv/bin/python3

# %%
import random

marks = [random.randint(45,100) for i in range(1,200)]
marks
# Out:
# [57,
#  54,
#  82,
#  98,
#  71,
#  83,
#  47,
#  67,
#  86,
#  54,
#  49,
#  62,
#  76,
#  83,
#  61,
#  84,
#  63,
#  65,
#  95,
#  76,
#  48,
#  84,
#  92,
#  77,
#  73,
#  57,
#  62,
#  59,
#  77,
#  49,
#  78,
#  97,
#  54,
#  72,
#  87,
#  92,
#  48,
#  64,
#  99,
#  47,
#  84,
#  68,
#  59,
#  58,
#  69,
#  70,
#  84,
#  47,
#  73,
#  92,
#  66,
#  76,
#  63,
#  74,
#  85,
#  82,
#  61,
#  59,
#  50,
#  59,
#  60,
#  97,
#  51,
#  50,
#  82,
#  50,
#  76,
#  67,
#  65,
#  71,
#  64,
#  57,
#  47,
#  96,
#  86,
#  77,
#  81,
#  76,
#  46,
#  95,
#  95,
#  65,
#  52,
#  51,
#  51,
#  57,
#  54,
#  61,
#  57,
#  69,
#  78,
#  57,
#  82,
#  87,
#  69,
#  55,
#  51,
#  47,
#  71,
#  63,
#  83,
#  96,
#  90,
#  56,
#  62,
#  51,
#  97,
#  88,
#  56,
#  55,
#  76,
#  89,
#  45,
#  69,
#  64,
#  76,
#  88,
#  53,
#  52,
#  74,
#  81,
#  82,
#  72,
#  67,
#  61,
#  52,
#  67,
#  98,
#  70,
#  77,
#  46,
#  51,
#  88,
#  99,
#  45,
#  59,
#  94,
#  86,
#  59,
#  92,
#  81,
#  65,
# ...

# %%
subscribers_df = pd.read_csv("/home/zoro/Downloads/subscribers.csv")
subscribers_df
# Out:
#        Unnamed: 0           user_id age_group city_tier subscription_date  \
# 0               0  UIDJS0000751588f     18-24    Tier 1        2024-06-10
# 1               1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09
# 2               2  UIDJS00010d7fa1e     25-34    Tier 1        2024-08-08
# 3               3  UIDJS00013411a85     35-44    Tier 2        2024-05-31
# 4               4  UIDJS0003a3f54cf     35-44    Tier 1        2024-09-20
# ...           ...               ...       ...       ...               ...
# 44615       44615  UIDJSfffbb38249e     25-34    Tier 2        2024-11-12
# 44616       44616  UIDJSfffbd759005       45+    Tier 1        2024-05-21
# 44617       44617  UIDJSfffebd3002b     25-34    Tier 1        2024-09-27
# 44618       44618  UIDJSffff6698084     35-44    Tier 3        2024-10-12
# 44619       44619  UIDJSffffe298c56     25-34    Tier 2        2024-09-10
#
#       subscription_plan last_active_date plan_change_date  \
# ...

# %%
subscribers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44620 entries, 0 to 44619
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             44620 non-null  int64
#  1   user_id                44620 non-null  str
#  2   age_group              44620 non-null  str
#  3   city_tier              44620 non-null  str
#  4   subscription_date      44620 non-null  str
#  5   subscription_plan      44620 non-null  str
#  6   last_active_date       6652 non-null   str
#  7   plan_change_date       7090 non-null   str
#  8   new_subscription_plan  7090 non-null   str
# dtypes: int64(1), str(8)
# memory usage: 3.1 MB

# %%
subscribers_df["subscription_date"] = subscribers_df["subscription_date"].astype

# %%
subscribers_df["subscription_date"]
# Out:
# 0        <bound method NDFrame.astype of 0        <boun...
# 1        <bound method NDFrame.astype of 0        <boun...
# 2        <bound method NDFrame.astype of 0        <boun...
# 3        <bound method NDFrame.astype of 0        <boun...
# 4        <bound method NDFrame.astype of 0        <boun...
#                                ...
# 44615    <bound method NDFrame.astype of 0        <boun...
# 44616    <bound method NDFrame.astype of 0        <boun...
# 44617    <bound method NDFrame.astype of 0        <boun...
# 44618    <bound method NDFrame.astype of 0        <boun...
# 44619    <bound method NDFrame.astype of 0        <boun...
# Name: subscription_date, Length: 44620, dtype: object

# %%
subscribers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44620 entries, 0 to 44619
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             44620 non-null  int64
#  1   user_id                44620 non-null  str
#  2   age_group              44620 non-null  str
#  3   city_tier              44620 non-null  str
#  4   subscription_date      44620 non-null  object
#  5   subscription_plan      44620 non-null  str
#  6   last_active_date       6652 non-null   str
#  7   plan_change_date       7090 non-null   str
#  8   new_subscription_plan  7090 non-null   str
# dtypes: int64(1), object(1), str(7)
# memory usage: 3.1+ MB

# %%
subscribers_df["subscription_date"].head(10)
# Out:
# 0    <bound method NDFrame.astype of 0        <boun...
# 1    <bound method NDFrame.astype of 0        <boun...
# 2    <bound method NDFrame.astype of 0        <boun...
# 3    <bound method NDFrame.astype of 0        <boun...
# 4    <bound method NDFrame.astype of 0        <boun...
# 5    <bound method NDFrame.astype of 0        <boun...
# 6    <bound method NDFrame.astype of 0        <boun...
# 7    <bound method NDFrame.astype of 0        <boun...
# 8    <bound method NDFrame.astype of 0        <boun...
# 9    <bound method NDFrame.astype of 0        <boun...
# Name: subscription_date, dtype: object

# %%
subscribers_df.dtypes
# Out:
# Unnamed: 0                int64
# user_id                     str
# age_group                   str
# city_tier                   str
# subscription_date        object
# subscription_plan           str
# last_active_date            str
# plan_change_date            str
# new_subscription_plan       str
# dtype: object

# %%
subscribers_df["subscription_date"].head(10)
# Out:
# 0    <bound method NDFrame.astype of 0        <boun...
# 1    <bound method NDFrame.astype of 0        <boun...
# 2    <bound method NDFrame.astype of 0        <boun...
# 3    <bound method NDFrame.astype of 0        <boun...
# 4    <bound method NDFrame.astype of 0        <boun...
# 5    <bound method NDFrame.astype of 0        <boun...
# 6    <bound method NDFrame.astype of 0        <boun...
# 7    <bound method NDFrame.astype of 0        <boun...
# 8    <bound method NDFrame.astype of 0        <boun...
# 9    <bound method NDFrame.astype of 0        <boun...
# Name: subscription_date, dtype: object

# %%
import pandas as pd

subscribers_df = pd.read_csv("/home/zoro/Downloads/subscribers.csv")

# %%
subscribers_df["subscription_date"].head()
# Out:
# 0    2024-06-10
# 1    2024-11-09
# 2    2024-08-08
# 3    2024-05-31
# 4    2024-09-20
# Name: subscription_date, dtype: str

# %%
subscribers_df["subscription_date"] = pd.to_datetime(subscribers_df["subscription_date"])
subscribers_df["plan_change_date"] = pd.to_datetime(subscribers_df["plan_change_date"])
subscribers_df["last_active_date"] = pd.to_datetime(subscribers_df["last_active_date"])

# %%
subscribers_df.dtypes
# Out:
# Unnamed: 0                        int64
# user_id                             str
# age_group                           str
# city_tier                           str
# subscription_date        datetime64[us]
# subscription_plan                   str
# last_active_date         datetime64[us]
# plan_change_date         datetime64[us]
# new_subscription_plan               str
# dtype: object

# %%
subscribers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44620 entries, 0 to 44619
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             44620 non-null  int64
#  1   user_id                44620 non-null  str
#  2   age_group              44620 non-null  str
#  3   city_tier              44620 non-null  str
#  4   subscription_date      44620 non-null  datetime64[us]
#  5   subscription_plan      44620 non-null  str
#  6   last_active_date       6652 non-null   datetime64[us]
#  7   plan_change_date       7090 non-null   datetime64[us]
#  8   new_subscription_plan  7090 non-null   str
# dtypes: datetime64[us](3), int64(1), str(5)
# memory usage: 3.1 MB

# %%
subscribers_df.describe()
# Out:
#          Unnamed: 0           subscription_date            last_active_date  \
# count  44620.000000                       44620                        6652
# mean   22309.500000  2024-06-18 07:26:00.376512  2024-09-07 08:07:04.293445
# min        0.000000         2024-01-01 00:00:00         2024-02-01 00:00:00
# 25%    11154.750000         2024-03-26 00:00:00         2024-07-06 00:00:00
# 50%    22309.500000         2024-06-19 12:00:00         2024-09-27 00:00:00
# 75%    33464.250000         2024-09-11 00:00:00         2024-11-18 00:00:00
# max    44619.000000         2024-11-30 00:00:00         2024-12-29 00:00:00
# std    12880.828842                         NaN                         NaN
#
#                  plan_change_date
# count                        7090
# mean   2024-08-10 08:20:38.928067
# min           2024-02-01 00:00:00
# 25%           2024-05-25 06:00:00
# 50%           2024-08-17 00:00:00
# 75%           2024-11-04 00:00:00
# max           2024-12-31 00:00:00
# ...

# %%
subscribers_df.describe(include=['object', 'str'])
# Out:
#                  user_id age_group city_tier subscription_plan  \
# count              44620     44620     44620             44620
# unique             44620         4         3                 3
# top     UIDJS0000751588f     25-34    Tier 1               VIP
# freq                   1     20069     25451             19157
#
#        new_subscription_plan
# count                   7090
# unique                     3
# top                  Premium
# freq                    3504

# %%
subscribers_df['subscription_plan'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='subscription_plan'>

# %%
tips_df = sns.load_dataset("tips")

# %%
tips_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
 WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
numerical_df = tips_df.select_dtypes(include=["int64", "Float64"])

# %%
categorical_df = tips_df.select_dtypes(include=["category"])

# %%
numerical_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   size        244 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 5.8 KB

# %%
numerical_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
categorical_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     244 non-null    category
#  1   smoker  244 non-null    category
#  2   day     244 non-null    category
#  3   time    244 non-null    category
# dtypes: category(4)
# memory usage: 1.6 KB

# %%
categorical_df.describe()
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tips_df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips_df["total_bill"].mean()
# Out:
# np.float64(19.78594262295082)

# %%
avg_size = tips_df["size"].mean()

# %%
avg_size = tips_df["size"].mean()

# %%
tips_df.fillna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 tips_df.fillna()
#
# TypeError: NDFrame.fillna() missing 1 required positional argument: 'value'

# %%
tips_df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
heights = [5,6,4.5,4.7,5,7,120]

# %%
sum(heights)/len(heights)
# Out:
# 21.74285714285714

# %%
h_sr = pd.Series(heights)

# %%
h_sr.mean()
# Out:
# np.float64(21.74285714285714)

# %%
h_sr.median()
# Out:
# np.float64(5.0)

# %%
import pandas as pd

churn_df = pd.read_csv("/home/zoro/Downloads/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Q1 = charges_info['25%']
Q1 = charges_info['75%']

IQR = Q3 - Q1
print(IQR)

lower_boundry = (Q1 - 1.5) * IQR
upper_boundry = (Q3 - 1.5) * IQR

# %% [raw]
# Outlier_removed = insurance_df[(insurance_df ['charges'] < upper_boundry) & (insurance_df)] ['charges']

# %%
outlier_removed_df.duplicated().sum()

# %%
outlier_removed_df.drop_duplicated()

# %%
outlier_removed_df.shape()

# %%
## categorical_df['day'].value_counts()
for col in categorical_df:
    print(categorical_df[col.value_counts())

# %%
for col in categorical_df:
    print(categorical_df[col.value_counts())

# %%
import numpy as np
# create normal data and transform it
normal_data = np.random.normal(loc=0, scale=1, size=1000)
skewed_data = np.exp(normal_data)

sns.histplot(skewed_data, kde=True)
#sns.histplot(normal data)
# Out:
# <Axes: ylabel='Count'>
